# %%
from random import*

def Ehr(N):
    c=1
    x=N-1
    while x!=N:
        r=randint(1,N)
        if r<=x:
            x=x-1
        else:
            x=x+1
        c=c+1
    return c

# %%
Ehr(2)
# Out:
# 2

# %%
Ehr(3)
# Out:
# 12

# %%
Ehr(4)
# Out:
# 2

# %%
Ehr(6)
# Out:
# 2

# %%
Ehr(100)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-f50feb0043aa> in <module>
# ----> 1 Ehr(100)
#
# <ipython-input-15-5cfa503d68fb> in Ehr(N)
#       5     x=N-1
#       6     while x!=N:
# ----> 7         r=randint(1,N)
#       8         if r<=x:
#       9             x=x-1
#
# ~\anaconda3\lib\random.py in randint(self, a, b)
#     246         """
#     247
# --> 248         return self.randrange(a, b+1)
#     249
#     250     def _randbelow_with_getrandbits(self, n):
#
# ~\anaconda3\lib\random.py in randrange(self, start, stop, step, _int)
#     222         width = istop - istart
#     223         if step == 1 and width > 0:
# --> 224             return istart + self._randbelow(width)
#     225         if step == 1:
#     226             raise ValueError("empty range for randrange() (%d, %d, %d)" % (istart, istop, width))
#
# ...

# %%
L=[]
for i in range (10000):
    L.append(Ehr(6))
print (L)
# Out:
# [76, 10, 68, 4, 2, 22, 2, 18, 2, 2, 94, 42, 18, 64, 22, 6, 2, 80, 10, 92, 42, 2, 50, 2, 12, 14, 320, 12, 132, 46, 28, 108, 4, 34, 2, 2, 52, 278, 30, 80, 94, 8, 360, 100, 86, 6, 90, 4, 126, 24, 242, 56, 80, 90, 202, 74, 78, 96, 134, 134, 8, 2, 290, 2, 30, 34, 2, 10, 66, 152, 18, 24, 362, 132, 20, 30, 4, 52, 108, 104, 2, 96, 24, 36, 60, 2, 40, 4, 20, 34, 2, 30, 50, 2, 118, 6, 266, 78, 70, 54, 6, 2, 56, 102, 6, 316, 144, 4, 44, 6, 66, 20, 14, 110, 38, 130, 58, 12, 98, 386, 10, 86, 52, 152, 220, 42, 4, 32, 274, 76, 90, 96, 50, 146, 144, 22, 4, 68, 118, 38, 2, 2, 76, 2, 92, 58, 44, 18, 78, 2, 194, 74, 2, 4, 2, 66, 4, 206, 4, 86, 2, 170, 32, 54, 96, 28, 4, 148, 2, 90, 2, 12, 10, 2, 216, 68, 44, 80, 4, 2, 44, 142, 60, 2, 6, 26, 88, 2, 4, 2, 44, 2, 80, 2, 54, 60, 2, 96, 2, 46, 16, 106, 30, 120, 56, 146, 2, 108, 64, 76, 232, 4, 68, 38, 248, 14, 2, 2, 82, 48, 2, 64, 34, 2, 110, 10, 2, 2, 264, 210, 220, 2, 484, 118, 2, 2, 86, 12, 94, 92, 4, 6, 4, 212, 92, 96, 2, 194, 28, 12, 30, 2, 12, 62, 154,
# ...

# %%
print (sum(L)/len(L))
# Out:
# 63.751
