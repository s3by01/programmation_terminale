# %%
from math import*
def U(n):
    y=-sqrt(n**2+1)
    return y

def Seuil (S):
    n=0
    while U(n)>=S:
        n=n+1
        print(n,U(n))
    return n

# %%
Seuil(-1000)
# Out:
# 1 -1.4142135623730951
# 2 -2.23606797749979
# 3 -3.1622776601683795
# 4 -4.123105625617661
# 5 -5.0990195135927845
# 6 -6.082762530298219
# 7 -7.0710678118654755
# 8 -8.06225774829855
# 9 -9.055385138137417
# 10 -10.04987562112089
# 11 -11.045361017187261
# 12 -12.041594578792296
# 13 -13.038404810405298
# 14 -14.035668847618199
# 15 -15.033296378372908
# 16 -16.0312195418814
# 17 -17.029386365926403
# 18 -18.027756377319946
# 19 -19.026297590440446
# 20 -20.024984394500787
# 21 -21.02379604162864
# 22 -22.02271554554524
# 23 -23.021728866442675
# 24 -24.020824298928627
# 25 -25.019992006393608
# 26 -26.019223662515376
# 27 -27.018512172212592
# 28 -28.0178514522438
# 29 -29.017236257093817
# 30 -30.01666203960727
# 31 -31.016124838541646
# 32 -32.01562118716424
# 33 -33.015148038438355
# 34 -34.0147027033899
# 35 -35.014282800023196
# 36 -36.013886210738214
# 37 -37.013511046643494
# 38 -38.01315561749642
# 39 -39.01281840626232
# 40 -40.01249804748511
# 41 -41.012193308819754
# ...
